# %%
from dlzx import torch as dlzx

# %%
root_dir = "../data/COVID-CT"

datasets = dlzx.MyImageDataset(root_dir)

# %%
train_ratio = 0.8
val_ratio = 0.1
test_ratio = 0.1

train_indices, val_indices, test_indices = dlzx.split_dataset_indices(datasets, train_ratio, val_ratio, test_ratio)

# %%
train_datasets = dlzx.split_dataset(datasets, train_indices)
val_datasets = dlzx.split_dataset(datasets, val_indices)
test_datasets = dlzx.split_dataset(datasets, test_indices)
