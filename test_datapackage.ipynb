# %%
import data_package

# %%
print("package has:",data_package.__all__)
# Out:
# package has: ['datasets', 'transforms']

# %%
from data_package.datasets import ImageClassificationDataset, ImageSegmentationDataset
from data_package.transforms import (
    Compose, Identity, ToTensor,
    Resize, RandomHorizontalFlip, Normalize,
)

print(ImageClassificationDataset, ImageSegmentationDataset)
print(Compose, Resize, ToTensor)
# Out:
# <class 'data_package.datasets.classification.ImageClassificationDataset'> <class 'data_package.datasets.segmentation.ImageSegmentationDataset'>
# <class 'data_package.transforms.base.Compose'> <class 'data_package.transforms.vision_basic.Resize'> <class 'data_package.transforms.base.ToTensor'>

# %%
from data_package.transforms import RandomVerticalFlip

print(RandomVerticalFlip)
# Out:
# <class 'data_package.transforms.vision_basic.RandomVerticalFlip'>
